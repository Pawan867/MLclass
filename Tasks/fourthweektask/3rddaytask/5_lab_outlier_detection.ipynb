# %% [markdown]
# ## Outlier Detection
# - In this notebook we'll look into the techniques on Outlier detection.
# - We will learn:
#   - z score
#   - Interquartile Range (IQR)
#   - Box Plot (from package seaborn)

# %% [markdown]
# **1. Outlier Detection using Z score**
# - Z score for item x gives how many standard deviation it is away from the mean.
# - As per Empirical Formulae:
#   - 68% of data points will be in the region of 1 standard deviation.
#   - 95% of data points will be in the region of 2 standard deviation.
#   - 99.7% of data points will be in the region of 3 standard deviation.
#
# - So, we can say any data points above `mean + 3*SD` or below `mean - 3*SD` as outliers
# - **`Formulae:`**
#   - The z-score formula is given by:
# $$ z = \frac{x - \mu}{\sigma} $$
#
#     Where,
#     - \( z \) represents the z-score.
#     - \( x \) is the individual data point.
#     - $ ( \mu ) $ is the mean of the data set.
#     - $( \sigma ) $ is the standard deviation of the data set.

# %%
# import package

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Asus\Desktop\MLearning Class\Tasks\fourthweektask\3rddaytask\5_lab_outlier_detection.ipynb Cell 3 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> # import package
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> import seaborn as sns
#
# ModuleNotFoundError: No module named 'numpy'

# %%
# Create Custom Dataset
dataset = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]
print(dataset)
# Out:
# [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]

# %% [markdown]
# **histogram plot**

# %%
sns.histplot(dataset, kde=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Asus\Desktop\MLearning Class\Tasks\fourthweektask\3rddaytask\5_lab_outlier_detection.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> sns.histplot(dataset, kde=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'sns' is not defined

# %% [markdown]
# - Above distribution is not normally distributed.
# - It is Right Tailed i.e. Right Skewed.
# - It may be due to some high values i.e. near to 100.
# - Let's try to detect outliers and remove if any.

# %% [markdown]
# **outlier detection**

# %%
# Detect outliers
THRESHOLD = 3


def detect_outliers(data):
  outliers = []

  # get mean
  mean = np.mean(data)

  # get standard deviation
  std = np.std(data)

  # Apply Z score for each and every point in the datasets.
  for i in data:
    z_score = (i - mean) / std

    # check for outliers
    # append to outlier list in the case of outlier
    if np.abs(z_score) > THRESHOLD:
      outliers.append(i)
  return outliers

# %%
# function call
outliers = detect_outliers(dataset)
outliers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Asus\Desktop\MLearning Class\Tasks\fourthweektask\3rddaytask\5_lab_outlier_detection.ipynb Cell 10 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # function call
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> outliers = detect_outliers(dataset)
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> outliers
#
# c:\Users\Asus\Desktop\MLearning Class\Tasks\fourthweektask\3rddaytask\5_lab_outlier_detection.ipynb Cell 10 in detect_outliers(data)
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=5'>6</a> outliers = []
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=7'>8</a> # get mean
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=8'>9</a> mean = np.mean(data)
#      <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=10'>11</a> # get standard deviation
#      <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> std = np.std(data)
#
# NameError: name 'np' is not defined

# %% [markdown]
# - Here, data points 102, 107, 108 falls under the section of outliers.

# %%
## **Remove Outliers** *italicized text*

# dataset_new = [item for item in dataset if item not in [102, 107, 108]]

# sns.histplot(dataset_new, kde=True)

# %% [markdown]
# **2. Outlier Detection using Interquartile Range (IQR)**
# - IQR is the difference between Q3 and Q1 i.e.
#   - `IQR = Q3 - Q1`,
#   where,
#   Q3 is 75% percentile
#   Q1 is 50% percentile
#
# - For Detecting Outliers we need to identify Lower Fence and Upper Fence i.e.
#   - Lower Fence = Q1 - 1.5 * IQR
#   - Upper Fence = Q3 + 1.5 * IQR
#
#   - For Outliers:
#     - Data points > Upper Fence or
#     - Data points < Lower Fence
#
# - **`Steps:`**
#   1. Sort the data in ascending Order.
#   2. Calculate Q1 and Q3.
#   3. Calculate IQR.
#   4. Find Lower Fence and Upper Fence.
#   5. Make Conclusion.

# %%
# redefine dataset

dataset = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19,
           107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15,
           12, 10, 14, 13, 15, 10]

# %%
## Step 1: sort the dataset in ascending order
dataset = sorted(dataset)
print(dataset)
# Out:
# [10, 10, 10, 10, 10, 11, 11, 12, 12, 12, 12, 12, 12, 12, 13, 13, 13, 13, 14, 14, 14, 14, 14, 14, 15, 15, 15, 15, 15, 17, 19, 102, 107, 108]

# %%
## Step 2: calculate Q1 and Q3
# Q1: 25% percentile
# Q3: 75% percentile

Q1, Q3 = np.percentile(dataset, [25, 75])

print(f"Q1: {Q1}")
print(f"Q3: {Q3}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Asus\Desktop\MLearning Class\Tasks\fourthweektask\3rddaytask\5_lab_outlier_detection.ipynb Cell 17 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> ## Step 2: calculate Q1 and Q3
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a> # Q1: 25% percentile
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> # Q3: 75% percentile
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a> Q1, Q3 = np.percentile(dataset, [25, 75])
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X22sZmlsZQ%3D%3D?line=6'>7</a> print(f"Q1: {Q1}")
#       <a href='vscode-notebook-cell:/c%3A/Users/Asus/Desktop/MLearning%20Class/Tasks/fourthweektask/3rddaytask/5_lab_outlier_detection.ipynb#X22sZmlsZQ%3D%3D?line=7'>8</a> print(f"Q3: {Q3}")
#
# NameError: name 'np' is not defined

# %%
## Step 3: Compute IQR

iqr = Q3 - Q1

print(f"IQR: {iqr}")
# Out:
# IQR: 3.0

# %%
## Step 4: Compute Lower Fence and Upper Fence

lower_fence = Q1 - (1.5 * iqr)
upper_fence = Q3 + (1.5 * iqr)

print(f"Lower Fence: {lower_fence}")
print(f"Upper Fence: {upper_fence}")
# Out:
# Lower Fence: 7.5
# Upper Fence: 19.5

# %%
## Step 5: Make Conclusion

def detect_outlier_using_iqr(data, iqr, lower_fence, upper_fence):
  outliers = []
  for i in data:
    if i < lower_fence or i > upper_fence:
      outliers.append(i)

  return outliers

# %%
# function call
outliers = detect_outlier_using_iqr(dataset, iqr, lower_fence, upper_fence)
print(f'Detected Outliers:\n {outliers}')
# Out:
# Detected Outliers:
#  [102, 107, 108]

# %% [markdown]
# ```
# - This means the detected Outliers using Z-score and IQR are same.
# - Here data points [102, 107, 108] are considered as an outliers.
# - This is handled in data preparations phase of Data science Methodology.
# ```

# %% [markdown]
# **3. Outliers Detection using Box plot**
# - Box plots are great way to visualize numeric data.
# - In order to draw Box plot, we need:
#   1. Minimum
#   2. First Quartile (Q1)
#   3. Median
#   4. Third Quartile (Q3)
#   5. Maximum
#
# - Let's use seaborn package to draw Box plot.

# %%
# redefine dataset
dataset = [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]
print(dataset)
# Out:
# [11, 10, 12, 14, 12, 15, 14, 13, 15, 102, 12, 14, 17, 19, 107, 10, 13, 12, 14, 12, 108, 12, 11, 14, 13, 15, 10, 15, 12, 10, 14, 13, 15, 10]

# %%
# Draw Box plot

plt.figure(figsize=(8, 6)) # set the figure size
sns.boxplot(data=dataset, color='skyblue') # create the box plot
plt.xlabel('Data')
plt.ylabel('Values')
plt.title('Box plot of Data points')
plt.show()

# %% [markdown]
# From above box plot also, we get the 3 values around 100 as outliers. Since it is above Maximum values of our Box plot.

# %% [markdown]
# ### Assignments:
#
# **`Q. From the above dataset remove detected outliers and draw the histogram plot to see data distributions.`**
