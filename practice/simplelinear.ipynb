# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Salary_Data.csv')

# %%
df.head(10)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
# 5              2.9  56642.0
# 6              3.0  60150.0
# 7              3.2  54445.0
# 8              3.2  64445.0
# 9              3.7  57189.0

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,  test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     YearsExperience
# 1               1.3
# 0               1.1
# 14              4.5
# 9               3.7
# 21              7.1
# 19              6.0

# %%
y_test
# Out:
# 1     46205.0
# 0     39343.0
# 14    61111.0
# 9     57189.0
# 21    98273.0
# 19    93940.0
# Name: Salary, dtype: float64

# %%
lr.predict(X_test.iloc[5].values.reshape(1,1))
# Out:
# c:\Users\Asus\Desktop\MLearning Class\virtualenv\environment\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([81810.69046455])

# %%
plt.scatter(df['YearsExperience'], df['Salary'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
m = lr.coef_

# %%
b = lr.intercept_

# %%
# y = mx+c
m*2.9+b
# Out:
# array([52144.9711197])
